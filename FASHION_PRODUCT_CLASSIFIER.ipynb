# %%
# !pip install opendatasets
# Out:
# Collecting opendatasets
#   Downloading opendatasets-0.1.22-py3-none-any.whl (15 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from opendatasets) (4.66.1)
# Requirement already satisfied: kaggle in /usr/local/lib/python3.10/dist-packages (from opendatasets) (1.5.16)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from opendatasets) (8.1.7)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.10/dist-packages (from kaggle->opendatasets) (1.16.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from kaggle->opendatasets) (2023.11.17)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from kaggle->opendatasets) (2.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from kaggle->opendatasets) (2.31.0)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.10/dist-packages (from kaggle->opendatasets) (8.0.1)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from kaggle->opendatasets) (2.0.7)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from kaggle->opendatasets) (6.1.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->kaggle->opendatasets) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.10/dist-packages (from python-slugify->kaggle->opendatasets) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle->opendatasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle->opendatasets) (3.6)
# Installing collected packages: opendatasets
# Successfully installed opendatasets-0.1.22

# %%
import opendatasets as od

# %%
od.download("https://www.kaggle.com/paramaggarwal/fashion-product-images-small")
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: anaumsharif
# Your Kaggle Key: ··········
# Downloading fashion-product-images-small.zip to ./fashion-product-images-small
# 100%|██████████| 565M/565M [00:08<00:00, 71.6MB/s]

# %%
cd fashion-product-images-small/
# Out:
# /content/fashion-product-images-small

# %%
import pandas as pd

# %%
df = pd.read_csv("styles.csv",on_bad_lines='skip')

# %%
df.head(10)
# Out:
#       id gender masterCategory subCategory  articleType baseColour  season  \
# 0  15970    Men        Apparel     Topwear       Shirts  Navy Blue    Fall
# 1  39386    Men        Apparel  Bottomwear        Jeans       Blue  Summer
# 2  59263  Women    Accessories     Watches      Watches     Silver  Winter
# 3  21379    Men        Apparel  Bottomwear  Track Pants      Black    Fall
# 4  53759    Men        Apparel     Topwear      Tshirts       Grey  Summer
# 5   1855    Men        Apparel     Topwear      Tshirts       Grey  Summer
# 6  30805    Men        Apparel     Topwear       Shirts      Green  Summer
# 7  26960  Women        Apparel     Topwear       Shirts     Purple  Summer
# 8  29114    Men    Accessories       Socks        Socks  Navy Blue  Summer
# 9  30039    Men    Accessories     Watches      Watches      Black  Winter
#
#      year   usage                             productDisplayName
# 0  2011.0  Casual               Turtle Check Men Navy Blue Shirt
# 1  2012.0  Casual             Peter England Men Party Blue Jeans
# 2  2016.0  Casual                       Titan Women Silver Watch
# 3  2011.0  Casual  Manchester United Men Solid Black Track Pants
# 4  2012.0  Casual                          Puma Men Grey T-shirt
# 5  2011.0  Casual           Inkfruit Mens Chain Reaction T-shirt
# 6  2012.0  Ethnic               Fabindia Men Striped Green Shirt
# 7  2012.0  Casual                  Jealous 21 Women Purple Shirt
# 8  2012.0  Casual                       Puma Men Pack of 3 Socks
# 9  2016.0  Casual                         Skagen Men Black Watch

# %%
df['image'] = df.apply(lambda row: str(row['id']) + ".jpg", axis=1)

# %%
df.head(10)
# Out:
#       id gender masterCategory subCategory  articleType baseColour  season  \
# 0  15970    Men        Apparel     Topwear       Shirts  Navy Blue    Fall
# 1  39386    Men        Apparel  Bottomwear        Jeans       Blue  Summer
# 2  59263  Women    Accessories     Watches      Watches     Silver  Winter
# 3  21379    Men        Apparel  Bottomwear  Track Pants      Black    Fall
# 4  53759    Men        Apparel     Topwear      Tshirts       Grey  Summer
# 5   1855    Men        Apparel     Topwear      Tshirts       Grey  Summer
# 6  30805    Men        Apparel     Topwear       Shirts      Green  Summer
# 7  26960  Women        Apparel     Topwear       Shirts     Purple  Summer
# 8  29114    Men    Accessories       Socks        Socks  Navy Blue  Summer
# 9  30039    Men    Accessories     Watches      Watches      Black  Winter
#
#      year   usage                             productDisplayName      image
# 0  2011.0  Casual               Turtle Check Men Navy Blue Shirt  15970.jpg
# 1  2012.0  Casual             Peter England Men Party Blue Jeans  39386.jpg
# 2  2016.0  Casual                       Titan Women Silver Watch  59263.jpg
# 3  2011.0  Casual  Manchester United Men Solid Black Track Pants  21379.jpg
# 4  2012.0  Casual                          Puma Men Grey T-shirt  53759.jpg
# 5  2011.0  Casual           Inkfruit Mens Chain Reaction T-shirt   1855.jpg
# 6  2012.0  Ethnic               Fabindia Men Striped Green Shirt  30805.jpg
# 7  2012.0  Casual                  Jealous 21 Women Purple Shirt  26960.jpg
# 8  2012.0  Casual                       Puma Men Pack of 3 Socks  29114.jpg
# 9  2016.0  Casual                         Skagen Men Black Watch  30039.jpg

# %%
df = df.sample(frac=1)

# %%
df.head(10)
# Out:
#           id  gender masterCategory               subCategory   articleType  \
# 42993  59077   Women        Apparel                 Innerwear           Bra
# 28166  59748   Women        Apparel  Loungewear and Nightwear    Nightdress
# 36852   6727  Unisex       Footwear                Flip Flops    Flip Flops
# 17360  14013     Men        Apparel                   Topwear       Tshirts
# 42656  59084   Women        Apparel                 Innerwear           Bra
# 17636  44755   Women       Footwear                     Shoes  Sports Shoes
# 34692  20509   Women    Accessories                      Bags      Handbags
# 39227  52658   Women    Accessories                      Bags      Handbags
# 31911  39204   Women       Footwear                     Shoes         Heels
# 38060  38559     Men        Apparel                   Topwear       Tshirts
#
#       baseColour  season    year   usage  \
# 42993      White  Summer  2017.0  Casual
# 28166      Cream  Summer  2017.0  Casual
# 36852     Purple  Winter  2011.0  Casual
# 17360      Black    Fall  2011.0  Sports
# 42656      White  Summer  2017.0  Casual
# 17636       Grey  Summer  2012.0  Sports
# 34692       Teal  Winter  2015.0  Casual
# 39227      Black  Summer  2012.0  Casual
# 31911        Red  Winter  2015.0  Casual
# 38060     Purple  Summer  2012.0  Casual
#
#                                productDisplayName      image
# 42993                   Peri Peri Women White Bra  59077.jpg
# 28166                    Avirate Cream Nightdress  59748.jpg
# 36852          Puma Unisex Coral Purple Flip Flop   6727.jpg
# 17360              Nike Men Printed Black Tshirts  14013.jpg
# 42656                   Peri Peri Women White Bra  59084.jpg
# 17636  Globalite Women Grey Startech Sports Shoes  44755.jpg
# 34692         Baggit Women Varsh Taj Teal Handbag  20509.jpg
# 39227                 Mod-acc Women Black Handbag  52658.jpg
# 31911                     Catwalk Women Red Flats  39204.jpg
# 38060           Nike Men Polo Club Purple T-shirt  38559.jpg

# %%
df = df.sample(frac=1).reset_index(drop=True)

# %%
df.head(10)
# Out:
#       id gender masterCategory subCategory            articleType baseColour  \
# 0  50183  Women    Accessories        Bags               Handbags      Brown
# 1  52935  Women        Apparel       Saree                 Sarees      White
# 2  41850    Men    Accessories       Socks                  Socks      Black
# 3  36015    Men    Accessories       Belts                  Belts      Black
# 4  46122  Women    Accessories   Jewellery    Necklace and Chains     Silver
# 5  31819    Men    Accessories     Watches                Watches       Blue
# 6  28434  Women    Accessories     Watches                Watches      White
# 7  17101  Women    Accessories     Wallets                Wallets       Blue
# 8  36933  Women  Personal Care   Fragrance  Perfume and Body Mist     Purple
# 9  33154    Men        Apparel     Topwear                Tshirts       Blue
#
#    season    year   usage                     productDisplayName      image
# 0  Summer  2012.0  Casual           Paridhan Women Brown Handbag  50183.jpg
# 1  Summer  2012.0  Ethnic                FNF Printed Purple Sari  52935.jpg
# 2  Winter  2015.0  Casual            Genesis Men Pack of 3 Socks  41850.jpg
# 3  Summer  2012.0  Casual            OTLS Men Black Leather Belt  36015.jpg
# 4  Summer  2012.0  Ethnic        Adrika Silver Coloured Necklace  46122.jpg
# 5  Winter  2016.0  Casual  Titan Men Chronograph Blue Dial Watch  31819.jpg
# 6  Winter  2016.0  Casual     DKNY Women White Dial Watch NY8299  28434.jpg
# 7  Winter  2015.0  Casual   Lino Perros Women Flower Blue Wallet  17101.jpg
# 8  Spring  2017.0  Casual            Bulgari Women Omnia Perfume  36933.jpg
# 9  Summer  2012.0  Casual  Classic Polo Men Printed Blue T-shirt  33154.jpg

# %% [markdown]
# ### Preparing the ImageDataGenerator for training the model

# %%
# !pip install Keras-Preprocessing
# Out:
# Collecting Keras-Preprocessing
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 745.5 kB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from Keras-Preprocessing) (1.23.5)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from Keras-Preprocessing) (1.16.0)
# Installing collected packages: Keras-Preprocessing
# Successfully installed Keras-Preprocessing-1.1.2

# %%
from keras_preprocessing.image import ImageDataGenerator
batch_size = 256

# %%
image_generator = ImageDataGenerator(
    validation_split=0.2
)

# %%
training_generator = image_generator.flow_from_dataframe(
    dataframe=df,
    directory="images",
    x_col="image",
    y_col="masterCategory",
    target_size=(60,80),
    batch_size=batch_size,
    subset="training"
)
# Out:
# Found 35536 validated image filenames belonging to 7 classes.
# /usr/local/lib/python3.10/dist-packages/keras_preprocessing/image/dataframe_iterator.py:279: UserWarning: Found 5 invalid image filename(s) in x_col="image". These filename(s) will be ignored.
#   warnings.warn(

# %%
validation_generator = image_generator.flow_from_dataframe(
    dataframe=df,
    directory="images",
    x_col="image",
    y_col="masterCategory",
    target_size=(60,80),
    batch_size=batch_size,
    subset="validation"
)
# Out:
# Found 8883 validated image filenames belonging to 7 classes.
# /usr/local/lib/python3.10/dist-packages/keras_preprocessing/image/dataframe_iterator.py:279: UserWarning: Found 5 invalid image filename(s) in x_col="image". These filename(s) will be ignored.
#   warnings.warn(

# %%
classes = len(training_generator.class_indices)

# %%
classes
# Out:
# 7

# %% [markdown]
# ### Initializing the Model using Neural Network

# %%
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.layers import Dense

# %%
#Initializing our model
classifier = Sequential()

# %%
classifier.add(Conv2D(32,(3,3),input_shape = (60,80,3), activation = 'relu'))

classifier.add(MaxPooling2D(pool_size=(3, 3)))

classifier.add(Conv2D(32,(3,3), activation = 'relu'))

classifier.add(MaxPooling2D(pool_size=(3, 3)))
classifier.add(Flatten())

classifier.add(Dense(units=32,activation = 'relu'))
classifier.add(Dense(units=64,activation = 'relu'))
classifier.add(Dense(units=128,activation = 'relu'))
classifier.add(Dense(units=256,activation = 'relu'))
classifier.add(Dense(units=512,activation = 'relu'))

classifier.add(Dense(units=7,activation = 'softmax'))

# %%
classifier.compile(optimizer='adam',
              loss="categorical_crossentropy",
              metrics=['accuracy'])

# %% [markdown]
# ### Fitting Data in our Neural Network

# %%
from math import ceil

# %%
classifier.fit_generator(
    generator=training_generator,
    steps_per_epoch=ceil(0.8 * (df.shape[0] / batch_size)),

    validation_data=validation_generator,
    validation_steps=ceil(0.2 * (df.shape[0] / batch_size)),

    epochs=5,
    verbose=1
)
# Out:
# Epoch 1/5
# <ipython-input-26-82e6e0bcfcd0>:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   classifier.fit_generator(
# 139/139 [==============================] - 156s 1s/step - loss: 0.4791 - accuracy: 0.8608 - val_loss: 0.2045 - val_accuracy: 0.9356
# Epoch 2/5
# 139/139 [==============================] - 208s 1s/step - loss: 0.1842 - accuracy: 0.9426 - val_loss: 0.1853 - val_accuracy: 0.9431
# Epoch 3/5
# 139/139 [==============================] - 210s 1s/step - loss: 0.1453 - accuracy: 0.9557 - val_loss: 0.1476 - val_accuracy: 0.9544
# Epoch 4/5
# 139/139 [==============================] - 186s 1s/step - loss: 0.1239 - accuracy: 0.9620 - val_loss: 0.1467 - val_accuracy: 0.9577
# Epoch 5/5
# 139/139 [==============================] - 191s 1s/step - loss: 0.1045 - accuracy: 0.9691 - val_loss: 0.1432 - val_accuracy: 0.9592

# %%
loss, acc = classifier.evaluate_generator(validation_generator, steps=ceil(0.2 * (df.size / batch_size)))
print("\n%s: %.2f%%" % (classifier.metrics_names[1], acc * 100))
# Out:
# <ipython-input-27-6daebe74b45d>:1: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   loss, acc = classifier.evaluate_generator(validation_generator, steps=ceil(0.2 * (df.size / batch_size)))
# WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 382 batches). You may need to use the repeat() function when building your dataset.
# accuracy: 95.92%

# %%
classifier.save("model.h5")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
import numpy as np
from keras.preprocessing import image

# %%
filename = "15970.jpg"

# %%
from keras.models import load_model
new_model = load_model('model.h5')
new_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 58, 78, 32)        896
#
#  max_pooling2d (MaxPooling2  (None, 19, 26, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 17, 24, 32)        9248
#
#  max_pooling2d_1 (MaxPoolin  (None, 5, 8, 32)          0
#  g2D)
#
#  flatten (Flatten)           (None, 1280)              0
#
#  dense (Dense)               (None, 32)                40992
#
#  dense_1 (Dense)             (None, 64)                2112
#
#  dense_2 (Dense)             (None, 128)               8320
#
#  dense_3 (Dense)             (None, 256)               33024
#
#  dense_4 (Dense)             (None, 512)               131584
#
#  dense_5 (Dense)             (None, 7)                 3591
#
# =================================================================
# Total params: 229767 (897.53 KB)
# Trainable params: 229767 (897.53 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
test_image = image.load_img("images/"+filename,target_size=(60,80))
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis = 0)

# %%
result = new_model.predict(test_image)
print(result)
# Out:
# 1/1 [==============================] - 0s 242ms/step
# [[3.6021965e-03 9.9602938e-01 3.2537733e-04 3.8376733e-05 2.1684836e-09
#   3.3626666e-06 1.4429432e-06]]

# %%
val = np.argmax(result)
print(val)
# Out:
# 1

# %%
my_dict = training_generator.class_indices
key_list = list(my_dict.keys())
val_list = list(my_dict.values())
print(key_list[val])
# Out:
# Apparel
